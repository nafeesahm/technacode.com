# %% [markdown]
# # Pandas

# %% [markdown]
# #

# %%
import pandas as pd

# %% [markdown]
# # How to create a data

# %%
dict= { 'name': ["nafees", "anis", "sheesh", "faiz"],
       'city': ["muzaffarpur", "darbhanga", "patna", "delhi"],
        'marks': [66, 97, 87 , 60]
      }

# %%
dict
# Out:
# {'name': ['nafees', 'anis', 'sheesh', 'faiz'],
#  'city': ['muzaffarpur', 'darbhanga', 'patna', 'delhi'],
#  'marks': [66, 97, 87, 60]}

# %% [markdown]
# # make a Data Frame

# %%
df = pd.DataFrame(dict)

# %%
df
# Out:
#      name         city  marks
# 0  nafees  muzaffarpur     66
# 1    anis    darbhanga     97
# 2  sheesh        patna     87
# 3    faiz        delhi     60

# %% [markdown]
# # How to save data in csv format

# %%
df.to_csv("mydata.csv")

# %%
df
# Out:
#      name         city  marks
# 0  nafees  muzaffarpur     66
# 1    anis    darbhanga     97
# 2  sheesh        patna     87
# 3    faiz        delhi     60

# %%
df.to_csv("newdata.csv", index=False)           # index= False ,  index remove from data after save

# %%
df
# Out:
#      name         city  marks
# 0  nafees  muzaffarpur     66
# 1    anis    darbhanga     97
# 2  sheesh        patna     87
# 3    faiz        delhi     60

# %% [markdown]
# #

# %% [markdown]
# # How to Load dataset

# %%
data= pd.read_csv("abalone.csv")               # data reading

# %%
data
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
data.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
data.tail()
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12

# %%
data.head(4)
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10

# %% [markdown]
# #  how to get random data

# %%
data.sample()           # give us random data
# Out:
#     Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 888   F    0.68      0.56   0.195        1.7775           0.861
#
#      Viscera weight  Shell weight  Rings
# 888           0.322         0.415     11

# %%
data.sample(10)            # get 10 random data
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 3857   M   0.655     0.515   0.200        1.3730          0.4430
# 2744   M   0.480     0.375   0.120        0.5895          0.2535
# 2897   I   0.545     0.430   0.150        0.7420          0.3525
# 2607   F   0.625     0.490   0.165        1.1270          0.4770
# 2617   M   0.670     0.520   0.190        1.6385          0.8115
# 3739   F   0.650     0.525   0.165        1.2380          0.6470
# 2008   I   0.425     0.315   0.095        0.3675          0.1865
# 2563   I   0.440     0.355   0.120        0.4950          0.2310
# 2006   I   0.405     0.250   0.090        0.2875          0.1280
# 388    M   0.490     0.420   0.125        0.6090          0.2390
#
#       Viscera weight  Shell weight  Rings
# 3857          0.3375        0.4900     16
# 2744          0.1280        0.1720     11
# 2897          0.1580        0.2080     10
# 2607          0.2365        0.3185      9
# ...

# %% [markdown]
# # How to get all columns name

# %%
data.columns               # get every columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %% [markdown]
# # how to get information about data

# %%
data.info                  # get information about data
# Out:
# <bound method DataFrame.info of      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# ...

# %% [markdown]
# # how to check null value  in data

# %%
data.isnull()                       # get  null value from data
# Out:
#         Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0     False   False     False   False         False           False
# 1     False   False     False   False         False           False
# 2     False   False     False   False         False           False
# 3     False   False     False   False         False           False
# 4     False   False     False   False         False           False
# ...     ...     ...       ...     ...           ...             ...
# 4172  False   False     False   False         False           False
# 4173  False   False     False   False         False           False
# 4174  False   False     False   False         False           False
# 4175  False   False     False   False         False           False
# 4176  False   False     False   False         False           False
#
#       Viscera weight  Shell weight  Rings
# 0              False         False  False
# 1              False         False  False
# ...

# %%
data.isnull().sum()                 # get  null value from data
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# # Statics

# %%
data.describe()               # describe tha data in statical form
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %% [markdown]
# # Pandas....................................................

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # series

# %% [markdown]
# series -> 1d single input data
#
# dataframe-> 2d tabular data collection / set of data in tabular form

# %%
x = [1,2,3,4]
df = pd.Series(x)

# %%
print(df)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
print(type(df))
# Out:
# <class 'pandas.core.series.Series'>

# %%
s = ["nafees" , "ahmad" , "guru" , "madhur" , "raj"]
res = pd.Series(s)

# %%
print(res)
# Out:
# 0    nafees
# 1     ahmad
# 2      guru
# 3    madhur
# 4       raj
# dtype: object

# %%
res[1]
# Out:
# 'ahmad'

# %%
res[1:3]
# Out:
# 1    ahmad
# 2     guru
# dtype: object

# %%
res[1:-1]
# Out:
# 1     ahmad
# 2      guru
# 3    madhur
# dtype: object

# %% [markdown]
# # DataFrame

# %%
pd.DataFrame([1,23,4,4,5,56,6,6])
# Out:
#     0
# 0   1
# 1  23
# 2   4
# 3   4
# 4   5
# 5  56
# 6   6
# 7   6

# %%
dis = {
    'name' : ["nafees"], 
    'class': ['10'],
    'roll' : ['39']
      }
pd.DataFrame(dis)
# Out:
#      name class roll
# 0  nafees    10   39

# %% [markdown]
# read and write (csv data)

# %% [markdown]
# # write data

# %%
dict = {
    'name': ['x' , 'y' , 'z'],
    'age' : ['12',13,14],
    'marks' : ['32' , '33' , '90']
        }

# %%
s = pd.DataFrame(dict)

# %%
s
# Out:
#   name age marks
# 0    x  12    32
# 1    y  13    33
# 2    z  14    90

# %%
data = s.to_csv("mydata.csv")

# %%
print(data)
# Out:
# None

# %% [markdown]
# # Read

# %%
import pandas as pd

# %%
data = pd.read_csv("mydata.csv")

# %%
data.head()
# Out:
#    Unnamed: 0 name  age  marks
# 0           0    x   12     32
# 1           1    y   13     33
# 2           2    z   14     90

# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\NAFEES AHMAD\Machine Learning(CETPA)\Sample_Dataset.csv")

# %%
data.head()
# Out:
#    id  f1       f2  f3   f4  f5  f6  f7  f8  f9  ...   f26  f27   f28  f29  \
# 0   1   1  17.2131   1  1.0   1   3   2   3   1  ...   NaN  1.0   9.0    1
# 1   2  35   0.1747   1  1.0   2   1   1   2   2  ...  12.0  1.0  10.0    1
# 2   3   1  35.3943   1  NaN   2   2   2   2   2  ...  30.0  1.0   9.0    1
# 3   4   1   4.4873   1  1.0   1   1   1   2   1  ...   NaN  1.0   9.0    1
# 4   5   1      NaN   1  NaN   1   1   1   1   1  ...  30.0  1.0  10.0    1
#
#     f30   f31         f32  f33  f34  obj1
# 0  40.0  13.0   32.766370  NaN  NaN     0
# 1  12.0  23.0  210.567669  NaN  NaN     0
# 2  24.0  16.0    0.000111  NaN  NaN     1
# 3  36.0   7.0    9.380889  NaN  NaN     0
# 4  12.0  20.0   28.089135  NaN  NaN     0
#
# [5 rows x 36 columns]

# %% [markdown]
# # Analysis

# %%
data.head(70)
# Out:
#     id  f1       f2  f3   f4  f5  f6  f7  f8  f9  ...   f26  f27   f28  f29  \
# 0    1   1  17.2131   1  1.0   1   3   2   3   1  ...   NaN  1.0   9.0    1
# 1    2  35   0.1747   1  1.0   2   1   1   2   2  ...  12.0  1.0  10.0    1
# 2    3   1  35.3943   1  NaN   2   2   2   2   2  ...  30.0  1.0   9.0    1
# 3    4   1   4.4873   1  1.0   1   1   1   2   1  ...   NaN  1.0   9.0    1
# 4    5   1      NaN   1  NaN   1   1   1   1   1  ...  30.0  1.0  10.0    1
# ..  ..  ..      ...  ..  ...  ..  ..  ..  ..  ..  ...   ...  ...   ...  ...
# 65  66   1  21.0357   1  2.0   3   3   2   2   3  ...  12.0  1.0  12.0    1
# 66  67  16      NaN   1  NaN   1   1   1   1   1  ...  12.0  1.0   9.0    1
# 67  68   1  84.1615   1  1.0   1   2   2   1   1  ...  12.0  1.0  12.0    1
# 68  69   1   6.7227   1  2.0   1   6   1   1   1  ...  36.0  1.0  12.0    1
# 69  70  38  11.4304   1  1.0   2   3   2   4   1  ...  12.0  1.0  12.0    1
#
#      f30   f31         f32  f33  f34  obj1
# ...

# %%
data.tail(5)
# Out:
#         id  f1        f2  f3   f4  f5  f6  f7  f8  f9  ...   f26  f27   f28  \
# 4523  4524  29    5.7576   1  1.0   3   2   2   2   1  ...   NaN  NaN  10.0
# 4524  4525   2  107.7430   1  1.0   3   4   3   1   1  ...  18.0  NaN  13.0
# 4525  4526   1    1.9364   1  1.0   4   7   4   4   1  ...   NaN  NaN   NaN
# 4526  4527   1    7.6795   1  3.0   2   4   2   2   2  ...  30.0  NaN  10.0
# 4527  4528   1   80.0871   1  1.0   2   4   4   1   2  ...   NaN  NaN   NaN
#
#       f29   f30   f31       f32    f33      f34  obj1
# 4523    1   NaN  32.0  236.1707    NaN  63.0541     0
# 4524    1  48.0  27.0    2.7998    NaN      NaN     1
# 4525    1   NaN   NaN  205.8064    NaN  15.9357     1
# 4526    1  60.0  10.0    1.6587  533.0      NaN     0
# 4527    1   NaN   NaN    2.9802    NaN      NaN     1
#
# [5 rows x 36 columns]

# %% [markdown]
# # sample           - > to find random data

# %%
data.sample(5)
# Out:
#         id  f1       f2  f3   f4  f5  f6  f7  f8  f9  ...   f26  f27   f28  \
# 4327  4328   2   0.5228   1  1.0   1   1   1   3   1  ...  30.0  1.0  10.0
# 1204  1205   1  20.1916   2  1.0   2   5   4   3   2  ...  12.0  1.0  12.0
# 4201  4202  51  28.3245   1  1.0   1   2   3   2   1  ...  18.0  1.0   7.0
# 2661  2662  16  65.0921   2  1.0   1   2   1   1   1  ...  62.0  1.0   8.0
# 2299  2300   1   0.8379   2  1.0   1   1   1   1   1  ...  12.0  1.0  12.0
#
#       f29   f30   f31       f32  f33      f34  obj1
# 4327    1   6.0  23.0  348.5482  NaN      NaN     0
# 1204    1  36.0  20.0    1.6587  NaN      NaN     0
# 4201    1  60.0  16.0   11.5388  NaN  87.2784     0
# 2661    1  38.0  12.0  154.3043  NaN      NaN     0
# 2299    1  12.0  18.0   25.4504  NaN      NaN     1
#
# [5 rows x 36 columns]

# %%
# information

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4528 entries, 0 to 4527
# Data columns (total 36 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      4528 non-null   int64
#  1   f1      4528 non-null   int64
#  2   f2      3826 non-null   float64
#  3   f3      4528 non-null   int64
#  4   f4      4415 non-null   float64
#  5   f5      4528 non-null   int64
#  6   f6      4528 non-null   int64
#  7   f7      4528 non-null   int64
#  8   f8      4528 non-null   int64
#  9   f9      4528 non-null   int64
#  10  f10     271 non-null    float64
#  11  f11     4528 non-null   int64
#  12  f12     4426 non-null   float64
#  13  f13     4528 non-null   int64
#  14  f14     4528 non-null   int64
#  15  f15     4528 non-null   int64
#  16  f16     4528 non-null   int64
#  17  f17     4447 non-null   float64
#  18  f18     4528 non-null   int64
#  19  f19     4522 non-null   float64
#  20  f20     4528 non-null   int64
# ...

# %% [markdown]
# how to observe null in your dataset

# %%
data.isnull()
# Out:
#          id     f1     f2     f3     f4     f5     f6     f7     f8     f9  \
# 0     False  False  False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False  False  False
# 2     False  False  False  False   True  False  False  False  False  False
# 3     False  False  False  False  False  False  False  False  False  False
# 4     False  False   True  False   True  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 4523  False  False  False  False  False  False  False  False  False  False
# 4524  False  False  False  False  False  False  False  False  False  False
# 4525  False  False  False  False  False  False  False  False  False  False
# 4526  False  False  False  False  False  False  False  False  False  False
# 4527  False  False  False  False  False  False  False  False  False  False
#
# ...

# %%
data.head()
# Out:
#    id  f1       f2  f3   f4  f5  f6  f7  f8  f9  ...   f26  f27   f28  f29  \
# 0   1   1  17.2131   1  1.0   1   3   2   3   1  ...   NaN  1.0   9.0    1
# 1   2  35   0.1747   1  1.0   2   1   1   2   2  ...  12.0  1.0  10.0    1
# 2   3   1  35.3943   1  NaN   2   2   2   2   2  ...  30.0  1.0   9.0    1
# 3   4   1   4.4873   1  1.0   1   1   1   2   1  ...   NaN  1.0   9.0    1
# 4   5   1      NaN   1  NaN   1   1   1   1   1  ...  30.0  1.0  10.0    1
#
#     f30   f31         f32  f33  f34  obj1
# 0  40.0  13.0   32.766370  NaN  NaN     0
# 1  12.0  23.0  210.567669  NaN  NaN     0
# 2  24.0  16.0    0.000111  NaN  NaN     1
# 3  36.0   7.0    9.380889  NaN  NaN     0
# 4  12.0  20.0   28.089135  NaN  NaN     0
#
# [5 rows x 36 columns]

# %%
data.isnull().sum()
# Out:
# id         0
# f1         0
# f2       702
# f3         0
# f4       113
# f5         0
# f6         0
# f7         0
# f8         0
# f9         0
# f10     4257
# f11        0
# f12      102
# f13        0
# f14        0
# f15        0
# f16        0
# f17       81
# f18        0
# f19        6
# f20        0
# f21       81
# f22        0
# f23        0
# f24       81
# f25       58
# f26      373
# f27       85
# f28       34
# f29        0
# f30      352
# f31      102
# f32      125
# f33     4465
# f34     4303
# obj1       0
# dtype: int64

# %%
data[['f5' , 'f6']].isnull()
# Out:
#          f5     f6
# 0     False  False
# 1     False  False
# 2     False  False
# 3     False  False
# 4     False  False
# ...     ...    ...
# 4523  False  False
# 4524  False  False
# 4525  False  False
# 4526  False  False
# 4527  False  False
#
# [4528 rows x 2 columns]

# %%
print(data.columns)
# Out:
# Index(['id', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10',
#        'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20',
#        'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', 'f28', 'f29', 'f30',
#        'f31', 'f32', 'f33', 'f34', 'obj1'],
#       dtype='object')

# %%
data.describe()
# Out:
#                 id           f1           f2           f3           f4  \
# count  4528.000000  4528.000000  3826.000000  4528.000000  4415.000000
# mean   2264.500000    17.555433    94.969574     1.742933     1.177350
# std    1307.265339    37.329683   221.506158     1.281357     0.510456
# min       1.000000     1.000000     0.010500     1.000000     1.000000
# 25%    1132.750000     1.000000     1.024525     1.000000     1.000000
# 50%    2264.500000     2.000000    14.066950     1.000000     1.000000
# 75%    3396.250000    21.000000    69.130550     2.000000     1.000000
# max    4528.000000   431.000000  1698.983200    19.000000     9.000000
#
#                 f5           f6           f7           f8           f9  ...  \
# count  4528.000000  4528.000000  4528.000000  4528.000000  4528.000000  ...
# mean      1.400177     2.073984     1.480565     1.999779     1.234982  ...
# std       0.796347     1.604487     0.798205     1.653493     0.673257  ...
# ...

# %%
data.nunique()
# Out:
# id      4528
# f1       158
# f2      3622
# f3        10
# f4         8
# f5        10
# f6        15
# f7         7
# f8        18
# f9         8
# f10        1
# f11        1
# f12      209
# f13       27
# f14       35
# f15       40
# f16       54
# f17        1
# f18       80
# f19        1
# f20        1
# f21        1
# f22       37
# f23      444
# f24        1
# f25        2
# f26       85
# f27        1
# f28       11
# f29        1
# f30       89
# f31       35
# f32     3344
# f33       59
# f34      225
# obj1       2
# dtype: int64

# %%
data['f5'].nunique()
# Out:
# 10

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4523    False
# 4524    False
# 4525    False
# 4526    False
# 4527    False
# Length: 4528, dtype: bool

# %%
data.duplicated('f5').sum()
# Out:
# 4518

# %%
import seaborn as sns
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # handling missing data

# %% [markdown]
# row and col delete  --- > drop na
#
# ignore
#
# fillna
#
# duplicate
#
# central tendency-----> mean , median, mode

# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\NAFEES AHMAD\Machine Learning(CETPA)\calendar.csv')

# %%
data.head()
# Out:
#          date  wm_yr_wk    weekday  wday  month  year    d event_name_1  \
# 0  2011-01-29     11101   Saturday     1      1  2011  d_1          NaN
# 1  2011-01-30     11101     Sunday     2      1  2011  d_2          NaN
# 2  2011-01-31     11101     Monday     3      1  2011  d_3          NaN
# 3  2011-02-01     11101    Tuesday     4      2  2011  d_4          NaN
# 4  2011-02-02     11101  Wednesday     5      2  2011  d_5          NaN
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 0          NaN          NaN          NaN        0        0        0
# 1          NaN          NaN          NaN        0        0        0
# 2          NaN          NaN          NaN        0        0        0
# 3          NaN          NaN          NaN        1        1        0
# 4          NaN          NaN          NaN        1        0        1

# %%
data.shape
# Out:
# (1969, 14)

# %%
data.isnull().sum()
# Out:
# date               0
# wm_yr_wk           0
# weekday            0
# wday               0
# month              0
# year               0
# d                  0
# event_name_1    1807
# event_type_1    1807
# event_name_2    1964
# event_type_2    1964
# snap_CA            0
# snap_TX            0
# snap_WI            0
# dtype: int64

# %% [markdown]
# dropna

# %%
df = data.dropna(axis = 0)                # all nan data deleted from row

# %%
df.head()
# Out:
#             date  wm_yr_wk weekday  wday  month  year       d    event_name_1  \
# 85    2011-04-24     11113  Sunday     2      4  2011    d_86  OrthodoxEaster
# 827   2013-05-05     11315  Sunday     2      5  2013   d_828  OrthodoxEaster
# 1177  2014-04-20     11412  Sunday     2      4  2014  d_1178          Easter
# 1233  2014-06-15     11420  Sunday     2      6  2014  d_1234    NBAFinalsEnd
# 1968  2016-06-19     11621  Sunday     2      6  2016  d_1969    NBAFinalsEnd
#
#      event_type_1    event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 85      Religious          Easter     Cultural        0        0        0
# 827     Religious   Cinco De Mayo     Cultural        1        1        1
# 1177     Cultural  OrthodoxEaster    Religious        0        0        0
# 1233     Sporting    Father's day     Cultural        0        1        1
# 1968     Sporting    Father's day     Cultural        0        0        0

# %%
data.head()
# Out:
#          date  wm_yr_wk    weekday  wday  month  year    d event_name_1  \
# 0  2011-01-29     11101   Saturday     1      1  2011  d_1          NaN
# 1  2011-01-30     11101     Sunday     2      1  2011  d_2          NaN
# 2  2011-01-31     11101     Monday     3      1  2011  d_3          NaN
# 3  2011-02-01     11101    Tuesday     4      2  2011  d_4          NaN
# 4  2011-02-02     11101  Wednesday     5      2  2011  d_5          NaN
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 0          NaN          NaN          NaN        0        0        0
# 1          NaN          NaN          NaN        0        0        0
# 2          NaN          NaN          NaN        0        0        0
# 3          NaN          NaN          NaN        1        1        0
# 4          NaN          NaN          NaN        1        0        1

# %%
df1 = data.dropna(axis =1)

# %%
df1
# Out:
#             date  wm_yr_wk    weekday  wday  month  year       d  snap_CA  \
# 0     2011-01-29     11101   Saturday     1      1  2011     d_1        0
# 1     2011-01-30     11101     Sunday     2      1  2011     d_2        0
# 2     2011-01-31     11101     Monday     3      1  2011     d_3        0
# 3     2011-02-01     11101    Tuesday     4      2  2011     d_4        1
# 4     2011-02-02     11101  Wednesday     5      2  2011     d_5        1
# ...          ...       ...        ...   ...    ...   ...     ...      ...
# 1964  2016-06-15     11620  Wednesday     5      6  2016  d_1965        0
# 1965  2016-06-16     11620   Thursday     6      6  2016  d_1966        0
# 1966  2016-06-17     11620     Friday     7      6  2016  d_1967        0
# 1967  2016-06-18     11621   Saturday     1      6  2016  d_1968        0
# 1968  2016-06-19     11621     Sunday     2      6  2016  d_1969        0
#
#       snap_TX  snap_WI
# 0           0        0
# 1           0        0
# ...

# %%
df1.shape
# Out:
# (1969, 10)

# %% [markdown]
# fillna

# %%
data.head()
# Out:
#          date  wm_yr_wk    weekday  wday  month  year    d event_name_1  \
# 0  2011-01-29     11101   Saturday     1      1  2011  d_1          NaN
# 1  2011-01-30     11101     Sunday     2      1  2011  d_2          NaN
# 2  2011-01-31     11101     Monday     3      1  2011  d_3          NaN
# 3  2011-02-01     11101    Tuesday     4      2  2011  d_4          NaN
# 4  2011-02-02     11101  Wednesday     5      2  2011  d_5          NaN
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 0          NaN          NaN          NaN        0        0        0
# 1          NaN          NaN          NaN        0        0        0
# 2          NaN          NaN          NaN        0        0        0
# 3          NaN          NaN          NaN        1        1        0
# 4          NaN          NaN          NaN        1        0        1

# %%
data.isnull().any().sum()
# Out:
# 4

# %%
data1 = data.fillna(value= 1)

# %%
data1
# Out:
#             date  wm_yr_wk    weekday  wday  month  year       d  \
# 0     2011-01-29     11101   Saturday     1      1  2011     d_1
# 1     2011-01-30     11101     Sunday     2      1  2011     d_2
# 2     2011-01-31     11101     Monday     3      1  2011     d_3
# 3     2011-02-01     11101    Tuesday     4      2  2011     d_4
# 4     2011-02-02     11101  Wednesday     5      2  2011     d_5
# ...          ...       ...        ...   ...    ...   ...     ...
# 1964  2016-06-15     11620  Wednesday     5      6  2016  d_1965
# 1965  2016-06-16     11620   Thursday     6      6  2016  d_1966
# 1966  2016-06-17     11620     Friday     7      6  2016  d_1967
# 1967  2016-06-18     11621   Saturday     1      6  2016  d_1968
# 1968  2016-06-19     11621     Sunday     2      6  2016  d_1969
#
#       event_name_1 event_type_1  event_name_2 event_type_2  snap_CA  snap_TX  \
# 0                1            1             1            1        0        0
# ...

# %%
data2 = data.fillna(value=2)

# %%
data2
# Out:
#             date  wm_yr_wk    weekday  wday  month  year       d  \
# 0     2011-01-29     11101   Saturday     1      1  2011     d_1
# 1     2011-01-30     11101     Sunday     2      1  2011     d_2
# 2     2011-01-31     11101     Monday     3      1  2011     d_3
# 3     2011-02-01     11101    Tuesday     4      2  2011     d_4
# 4     2011-02-02     11101  Wednesday     5      2  2011     d_5
# ...          ...       ...        ...   ...    ...   ...     ...
# 1964  2016-06-15     11620  Wednesday     5      6  2016  d_1965
# 1965  2016-06-16     11620   Thursday     6      6  2016  d_1966
# 1966  2016-06-17     11620     Friday     7      6  2016  d_1967
# 1967  2016-06-18     11621   Saturday     1      6  2016  d_1968
# 1968  2016-06-19     11621     Sunday     2      6  2016  d_1969
#
#       event_name_1 event_type_1  event_name_2 event_type_2  snap_CA  snap_TX  \
# 0                2            2             2            2        0        0
# ...

# %%
f = data.fillna('backfill')

# %%
f.head()
# Out:
#          date  wm_yr_wk    weekday  wday  month  year    d event_name_1  \
# 0  2011-01-29     11101   Saturday     1      1  2011  d_1     backfill
# 1  2011-01-30     11101     Sunday     2      1  2011  d_2     backfill
# 2  2011-01-31     11101     Monday     3      1  2011  d_3     backfill
# 3  2011-02-01     11101    Tuesday     4      2  2011  d_4     backfill
# 4  2011-02-02     11101  Wednesday     5      2  2011  d_5     backfill
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 0     backfill     backfill     backfill        0        0        0
# 1     backfill     backfill     backfill        0        0        0
# 2     backfill     backfill     backfill        0        0        0
# 3     backfill     backfill     backfill        1        1        0
# 4     backfill     backfill     backfill        1        0        1

# %%
f1 = data.fillna(method ='backfill')

# %%
f1.head()
# Out:
#          date  wm_yr_wk    weekday  wday  month  year    d event_name_1  \
# 0  2011-01-29     11101   Saturday     1      1  2011  d_1    SuperBowl
# 1  2011-01-30     11101     Sunday     2      1  2011  d_2    SuperBowl
# 2  2011-01-31     11101     Monday     3      1  2011  d_3    SuperBowl
# 3  2011-02-01     11101    Tuesday     4      2  2011  d_4    SuperBowl
# 4  2011-02-02     11101  Wednesday     5      2  2011  d_5    SuperBowl
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 0     Sporting       Easter     Cultural        0        0        0
# 1     Sporting       Easter     Cultural        0        0        0
# 2     Sporting       Easter     Cultural        0        0        0
# 3     Sporting       Easter     Cultural        1        1        0
# 4     Sporting       Easter     Cultural        1        0        1

# %%
data.head()
# Out:
#          date  wm_yr_wk    weekday  wday  month  year    d event_name_1  \
# 0  2011-01-29     11101   Saturday     1      1  2011  d_1          NaN
# 1  2011-01-30     11101     Sunday     2      1  2011  d_2          NaN
# 2  2011-01-31     11101     Monday     3      1  2011  d_3          NaN
# 3  2011-02-01     11101    Tuesday     4      2  2011  d_4          NaN
# 4  2011-02-02     11101  Wednesday     5      2  2011  d_5          NaN
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 0          NaN          NaN          NaN        0        0        0
# 1          NaN          NaN          NaN        0        0        0
# 2          NaN          NaN          NaN        0        0        0
# 3          NaN          NaN          NaN        1        1        0
# 4          NaN          NaN          NaN        1        0        1

# %%
x = f1.fillna(method = 'ffill')

# %%
x.head()
# Out:
#          date  wm_yr_wk    weekday  wday  month  year    d event_name_1  \
# 0  2011-01-29     11101   Saturday     1      1  2011  d_1    SuperBowl
# 1  2011-01-30     11101     Sunday     2      1  2011  d_2    SuperBowl
# 2  2011-01-31     11101     Monday     3      1  2011  d_3    SuperBowl
# 3  2011-02-01     11101    Tuesday     4      2  2011  d_4    SuperBowl
# 4  2011-02-02     11101  Wednesday     5      2  2011  d_5    SuperBowl
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 0     Sporting       Easter     Cultural        0        0        0
# 1     Sporting       Easter     Cultural        0        0        0
# 2     Sporting       Easter     Cultural        0        0        0
# 3     Sporting       Easter     Cultural        1        1        0
# 4     Sporting       Easter     Cultural        1        0        1

# %%
w = data.fillna(method = 'pad')

# %%
w
# Out:
#             date  wm_yr_wk    weekday  wday  month  year       d  \
# 0     2011-01-29     11101   Saturday     1      1  2011     d_1
# 1     2011-01-30     11101     Sunday     2      1  2011     d_2
# 2     2011-01-31     11101     Monday     3      1  2011     d_3
# 3     2011-02-01     11101    Tuesday     4      2  2011     d_4
# 4     2011-02-02     11101  Wednesday     5      2  2011     d_5
# ...          ...       ...        ...   ...    ...   ...     ...
# 1964  2016-06-15     11620  Wednesday     5      6  2016  d_1965
# 1965  2016-06-16     11620   Thursday     6      6  2016  d_1966
# 1966  2016-06-17     11620     Friday     7      6  2016  d_1967
# 1967  2016-06-18     11621   Saturday     1      6  2016  d_1968
# 1968  2016-06-19     11621     Sunday     2      6  2016  d_1969
#
#         event_name_1 event_type_1  event_name_2 event_type_2  snap_CA  \
# 0                NaN          NaN           NaN          NaN        0
# ...

# %%
o = data.fillna(method = 'bfill' , limit = 10)
o
# Out:
#             date  wm_yr_wk    weekday  wday  month  year       d  \
# 0     2011-01-29     11101   Saturday     1      1  2011     d_1
# 1     2011-01-30     11101     Sunday     2      1  2011     d_2
# 2     2011-01-31     11101     Monday     3      1  2011     d_3
# 3     2011-02-01     11101    Tuesday     4      2  2011     d_4
# 4     2011-02-02     11101  Wednesday     5      2  2011     d_5
# ...          ...       ...        ...   ...    ...   ...     ...
# 1964  2016-06-15     11620  Wednesday     5      6  2016  d_1965
# 1965  2016-06-16     11620   Thursday     6      6  2016  d_1966
# 1966  2016-06-17     11620     Friday     7      6  2016  d_1967
# 1967  2016-06-18     11621   Saturday     1      6  2016  d_1968
# 1968  2016-06-19     11621     Sunday     2      6  2016  d_1969
#
#       event_name_1 event_type_1  event_name_2 event_type_2  snap_CA  snap_TX  \
# 0        SuperBowl     Sporting           NaN          NaN        0        0
# ...

# %%
o = data.fillna(method = 'bfill' , limit = 1)

# %%
o.head(10)
# Out:
#          date  wm_yr_wk    weekday  wday  month  year     d event_name_1  \
# 0  2011-01-29     11101   Saturday     1      1  2011   d_1          NaN
# 1  2011-01-30     11101     Sunday     2      1  2011   d_2          NaN
# 2  2011-01-31     11101     Monday     3      1  2011   d_3          NaN
# 3  2011-02-01     11101    Tuesday     4      2  2011   d_4          NaN
# 4  2011-02-02     11101  Wednesday     5      2  2011   d_5          NaN
# 5  2011-02-03     11101   Thursday     6      2  2011   d_6          NaN
# 6  2011-02-04     11101     Friday     7      2  2011   d_7          NaN
# 7  2011-02-05     11102   Saturday     1      2  2011   d_8    SuperBowl
# 8  2011-02-06     11102     Sunday     2      2  2011   d_9    SuperBowl
# 9  2011-02-07     11102     Monday     3      2  2011  d_10          NaN
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 0          NaN          NaN          NaN        0        0        0
# ...

# %%
o.tail(10)
# Out:
#             date  wm_yr_wk    weekday  wday  month  year       d  \
# 1959  2016-06-10     11619     Friday     7      6  2016  d_1960
# 1960  2016-06-11     11620   Saturday     1      6  2016  d_1961
# 1961  2016-06-12     11620     Sunday     2      6  2016  d_1962
# 1962  2016-06-13     11620     Monday     3      6  2016  d_1963
# 1963  2016-06-14     11620    Tuesday     4      6  2016  d_1964
# 1964  2016-06-15     11620  Wednesday     5      6  2016  d_1965
# 1965  2016-06-16     11620   Thursday     6      6  2016  d_1966
# 1966  2016-06-17     11620     Friday     7      6  2016  d_1967
# 1967  2016-06-18     11621   Saturday     1      6  2016  d_1968
# 1968  2016-06-19     11621     Sunday     2      6  2016  d_1969
#
#       event_name_1 event_type_1  event_name_2 event_type_2  snap_CA  snap_TX  \
# 1959           NaN          NaN           NaN          NaN        1        0
# 1960           NaN          NaN           NaN          NaN        0        1
# ...

# %% [markdown]
# central tendency theorem

# %%
# mean
# median
# mode

# %%
data.columns
# Out:
# Index(['date', 'wm_yr_wk', 'weekday', 'wday', 'month', 'year', 'd',
#        'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2',
#        'snap_CA', 'snap_TX', 'snap_WI'],
#       dtype='object')

# %%
data['wday'].mean()
# Out:
# 3.9974606399187405

# %%
data['wday'].median()
# Out:
# 4.0

# %%
data['wday'].mode()
# Out:
# 0    1
# 1    2
# dtype: int64
